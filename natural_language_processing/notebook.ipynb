# %% [markdown]
# Wakacje są blisko, wszyscy już myślą o wyjazdach - ale jak tu dobrze ocenić hotel, żeby jak najbardziej się nim cieszyć?
#
# Zadanie polega na stworzeniu modelu, który będzie klasyfikował liczbę gwiazdek przyznanych hotelowi (rating, klasa = liczba_gwiazdek - 1) na podstawie recenzji, jaką otrzymał (review).
# Wszelkie chwyty dozwolone :) Mogą Państwo przewidywać klasy w oparciu o klasyczną metodę bag of words, inne metody reprezentacji dokumentów (np. TF-IDF), korzystać z embeddingów, gotowych modeli językowych itd. Do dyspozycji mają Państwo dane treningowe, oczekuję od Państwa pliku csv z wygenerowanymi predykcjami.
# Proszę zwrócić uwagę na fakt, że jest to problem klasyfikacji wieloklasowej z mocno niezbalansowanym zbiorem danych!
# Proszę także Państwa o przetestowanie kilku (co najmniej trzech) podejść do klasyfikacji - mogą (ale nie muszą!) być to gotowe modele, najlepiej o różnych architekturach.
#
# Bardzo proszę, żeby zwrócili mi Państwo archiwum zip (wystarczy jedna osoba z zespołu), proszę też o zastosowanie się do instrukcji:
# - Archiwum i wszystkie pliki powinny być nazwane {poniedzialek/piatek}_nazwisko1_nazwisko2
# - W archiwum proszę (bez zbędnych podfolderów!) umieścić pliki ze swoim kodem i testowe predykcje nazwane zgodnie z sekwencją  {poniedzialek/piatek}_nazwisko1_nazwisko2.csv
# - Testowe predykcje powinny mieć kolejność zgodną z kolejnością sekwencji, do których się odnoszą w zbiorze testowym. Plik csv nie powinien mieć nagłówka ani indeksów.
#
# Proszę o dokładne dokumentowanie wykonanych eksperymentów!
#
# Uwaga: proszę dokładnie sprawdzić swoje rozwiązania i predykcje. W związku z końcem semestru, nie będzie możliwości dosyłania poprawek.

# %%
# import zipfile

# # Specify the path to the zip file
# zip_file_path = '/content/data.zip'

# # Specify the directory to extract the contents to
# extract_dir = '/content/data/'

# # Extract the zip file
# with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
#     zip_ref.extractall(extract_dir)

# # Check the extracted directory structure
# !ls {extract_dir}

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as data
import numpy as np
import pandas as pd
import nltk
from nltk import ngrams
from tqdm import tqdm

# %%
DATA_PATH = './data'
MODEL_PATH = './models'

# %%
train_data = pd.read_csv(f'{DATA_PATH}/train_data.csv')
test_data = pd.read_csv(f'{DATA_PATH}/test_data.csv')

# %% [markdown]
# ### Continuous Bag Of Words

# %%
CONTEXT_SIZE = 2
EMBEDDING_DIM = 10
EPOCHS_CBOW = 10

# %%
reviews = train_data['review']
ngrams = []
for review in reviews:
    review = review.lower().split()
    ngram = [
        (
            [review[i - j - 1] for j in range(CONTEXT_SIZE)] + [review[i + j + 1] for j in range(CONTEXT_SIZE)],
            review[i]
        )
        for i in range(CONTEXT_SIZE, len(review)-CONTEXT_SIZE)
        ]
    ngrams.extend(ngram)

vocab = set([word for review in reviews for word in review.lower().split()])

word_to_ix = {word: i for i, word in enumerate(vocab)}

ngrams
# Out:
# [(['not', 'location', 'excellent', 'hotel'], 'palace'),
#  (['palace', 'not', 'hotel', 'booke'], 'excellent'),
#  (['excellent', 'palace', 'booke', 'dthe'], 'hotel'),
#  (['hotel', 'excellent', 'dthe', 'hotel'], 'booke'),
#  (['booke', 'hotel', 'hotel', 'nh'], 'dthe'),
#  (['dthe', 'booke', 'nh', 'hotel'], 'hotel'),
#  (['hotel', 'dthe', 'hotel', 'site'], 'nh'),
#  (['nh', 'hotel', 'site', 'attractive'], 'hotel'),
#  (['hotel', 'nh', 'attractive', 'rate,'], 'site'),
#  (['site', 'hotel', 'rate,', 'room'], 'attractive'),
#  (['attractive', 'site', 'room', 'spacious'], 'rate,'),
#  (['rate,', 'attractive', 'spacious', 'quiet,'], 'room'),
#  (['room', 'rate,', 'quiet,', 'clean,'], 'spacious'),
#  (['spacious', 'room', 'clean,', 'hotel'], 'quiet,'),
#  (['quiet,', 'spacious', 'hotel', 'bit'], 'clean,'),
#  (['clean,', 'quiet,', 'bit', 'unpersonal'], 'hotel'),
#  (['hotel', 'clean,', 'unpersonal', 'big,'], 'bit'),
#  (['bit', 'hotel', 'big,', 'breakfast'], 'unpersonal'),
#  (['unpersonal', 'bit', 'breakfast', 'tremendous,'], 'big,'),
#  (['big,', 'unpersonal', 'tremendous,', 'teh'], 'breakfast'),
#  (['breakfast', 'big,', 'teh', 'breakfast'], 'tremendous,'),
#  (['tremendous,', 'breakfast', 'breakfast', 'room'], 'teh'),
#  (['teh', 'tremendous,', 'room', 'art'], 'breakfast'),
#  (['breakfast', 'teh', 'art', 'nouveau..'], 'room'),
#  (['room', 'breakfast', 'nouveau..', 'real'], 'art'),
#  (['art', 'room', 'real', 'experience,'], 'nouveau..'),
#  (['nouveau..', 'art', 'experience,', 'location'], 'real'),
#  (['real', 'nouveau..', 'location', 'ok'], 'experience,'),
#  (['experience,', 'real', 'ok', 'altough'], 'location'),
#  (['location', 'experience,', 'altough', 'busy'], 'ok'),
#  (['ok', 'location', 'busy', 'neighbourhood'], 'altough'),
#  (['altough', 'ok', 'neighbourhood', 'night,'], 'busy'),
#  (['busy', 'altough', 'night,', 'rooms'], 'neighbourhood'),
#  (['neighbourhood', 'busy', 'rooms', 'sound'], 'night,'),
#  (['night,', 'neighbourhood', 'sound', 'proof,'], 'rooms'),
#  (['rooms', 'night,', 'proof,', 'stayed'], 'sound'),
#  (['sound', 'rooms', 'stayed', 'hotels'], 'proof,'),
#  (['proof,', 'sound', 'hotels', 'amsterdam,'], 'stayed'),
#  (['stayed', 'proof,', 'amsterdam,', 'favorite,'], 'hotels'),
#  (['definitely', 'respite', 'place', 'stay'], 'not'),
#  (['not', 'definitely', 'stay', 'looking'], 'place'),
#  (['place', 'not', 'looking', 'ultra-modern'], 'stay'),
#  (['stay', 'place', 'ultra-modern', 'chic'], 'looking'),
#  (['looking', 'stay', 'chic', 'hotel'], 'ultra-modern'),
#  (['ultra-modern', 'looking', 'hotel', 'exudes'], 'chic'),
#  (['chic', 'ultra-modern', 'exudes', 'air'], 'hotel'),
#  (['hotel', 'chic', 'air', 'fading'], 'exudes'),
#  (['exudes', 'hotel', 'fading', 'glamour'], 'air'),
#  (['air', 'exudes', 'glamour', 'days'], 'fading'),
#  (['fading', 'air', 'days', 'gone,'], 'glamour'),
#  (['glamour', 'fading', 'gone,', 'lobby'], 'days'),
#  (['days', 'glamour', 'lobby', 'bar'], 'gone,'),
#  (['gone,', 'days', 'bar', 'restaurant'], 'lobby'),
#  (['lobby', 'gone,', 'restaurant', 'grand'], 'bar'),
#  (['bar', 'lobby', 'grand', 'expect'], 'restaurant'),
#  (['restaurant', 'bar', 'expect', 'place'], 'grand'),
#  (['grand', 'restaurant', 'place', 'cosy'], 'expect'),
#  (['expect', 'grand', 'cosy', 'feel'], 'place'),
#  (['place', 'expect', 'feel', 'homely.our'], 'cosy'),
#  (['cosy', 'place', 'homely.our', 'room'], 'feel'),
#  (['feel', 'cosy', 'room', 'suitably'], 'homely.our'),
#  (['homely.our', 'feel', 'suitably', 'large'], 'room'),
#  (['room', 'homely.our', 'large', 'high'], 'suitably'),
#  (['suitably', 'room', 'high', 'ceilings'], 'large'),
#  (['large', 'suitably', 'ceilings', 'match,'], 'high'),
#  (['high', 'large', 'match,', 'decor'], 'ceilings'),
#  (['ceilings', 'high', 'decor', 'woefully'], 'match,'),
#  (['match,', 'ceilings', 'woefully', 'outdated'], 'decor'),
#  (['decor', 'match,', 'outdated', 'actually'], 'woefully'),
#  (['woefully', 'decor', 'actually', 'refreshing'], 'outdated'),
#  (['outdated', 'woefully', 'refreshing', 'change'], 'actually'),
#  (['actually', 'outdated', 'change', 'staying'], 'refreshing'),
#  (['refreshing', 'actually', 'staying', 'character'], 'change'),
#  (['change', 'refreshing', 'character', 'place'], 'staying'),
#  (['staying', 'change', 'place', 'did'], 'character'),
#  (['character', 'staying', 'did', "n't"], 'place'),
#  (['place', 'character', "n't", 'feel'], 'did'),
#  (['did', 'place', 'feel', 'like'], "n't"),
#  (["n't", 'did', 'like', 'assembled'], 'feel'),
#  (['feel', "n't", 'assembled', 'entirely'], 'like'),
#  (['like', 'feel', 'entirely', 'flatpack'], 'assembled'),
#  (['assembled', 'like', 'flatpack', 'kits'], 'entirely'),
#  (['entirely', 'assembled', 'kits', 'ikea,'], 'flatpack'),
#  (['flatpack', 'entirely', 'ikea,', 'spotlessly'], 'kits'),
#  (['kits', 'flatpack', 'spotlessly', 'clean'], 'ikea,'),
#  (['ikea,', 'kits', 'clean', 'room'], 'spotlessly'),
#  (['spotlessly', 'ikea,', 'room', 'fresh'], 'clean'),
#  (['clean', 'spotlessly', 'fresh', 'temperatures'], 'room'),
#  (['room', 'clean', 'temperatures', 'perfectly'], 'fresh'),
#  (['fresh', 'room', 'perfectly', 'set'], 'temperatures'),
#  (['temperatures', 'fresh', 'set', 'centrally'], 'perfectly'),
#  (['perfectly', 'temperatures', 'centrally', 'offset'], 'set'),
#  (['set', 'perfectly', 'offset', 'climate'], 'centrally'),
#  (['centrally', 'set', 'climate', 'outside,'], 'offset'),
#  (['offset', 'centrally', 'outside,', 'bathroom'], 'climate'),
#  (['climate', 'offset', 'bathroom', 'immaculately'], 'outside,'),
#  (['outside,', 'climate', 'immaculately', 'kept'], 'bathroom'),
#  (['bathroom', 'outside,', 'kept', 'did'], 'immaculately'),
#  (['immaculately', 'bathroom', 'did', 'notice'], 'kept'),
#  (['kept', 'immaculately', 'notice', 'place'], 'did'),
#  (['did', 'kept', 'place', 'tile'], 'notice'),
#  (['notice', 'did', 'tile', 'really'], 'place'),
#  (['place', 'notice', 'really', 'fixed'], 'tile'),
#  (['tile', 'place', 'fixed', 'long'], 'really'),
#  (['really', 'tile', 'long', 'ago.there'], 'fixed'),
#  (['fixed', 'really', 'ago.there', 'things'], 'long'),
#  (['long', 'fixed', 'things', 'room'], 'ago.there'),
#  (['ago.there', 'long', 'room', 'did'], 'things'),
#  (['things', 'ago.there', 'did', "n't"], 'room'),
#  (['room', 'things', "n't", 'like,'], 'did'),
#  (['did', 'room', 'like,', 'firstly'], "n't"),
#  (["n't", 'did', 'firstly', 'supply'], 'like,'),
#  (['like,', "n't", 'supply', 'complimentary'], 'firstly'),
#  (['firstly', 'like,', 'complimentary', 'bottle'], 'supply'),
#  (['supply', 'firstly', 'bottle', 'mineral'], 'complimentary'),
#  (['complimentary', 'supply', 'mineral', 'water'], 'bottle'),
#  (['bottle', 'complimentary', 'water', 'day'], 'mineral'),
#  (['mineral', 'bottle', 'day', 'no'], 'water'),
#  (['water', 'mineral', 'no', 'tea'], 'day'),
#  (['day', 'water', 'tea', 'coffee'], 'no'),
#  (['no', 'day', 'coffee', 'making'], 'tea'),
#  (['tea', 'no', 'making', 'facilities,'], 'coffee'),
#  (['coffee', 'tea', 'facilities,', 'secondly'], 'making'),
#  (['making', 'coffee', 'secondly', 'bedside'], 'facilities,'),
#  (['facilities,', 'making', 'bedside', 'cabinets'], 'secondly'),
#  (['secondly', 'facilities,', 'cabinets', 'old'], 'bedside'),
#  (['bedside', 'secondly', 'old', 'radio'], 'cabinets'),
#  (['cabinets', 'bedside', 'radio', 'built'], 'old'),
#  (['old', 'cabinets', 'built', 'strangely'], 'radio'),
#  (['radio', 'old', 'strangely', 'disconnected,'], 'built'),
#  (['built', 'radio', 'disconnected,', 'bit'], 'strangely'),
#  (['strangely', 'built', 'bit', 'shame'], 'disconnected,'),
#  (['disconnected,', 'strangely', 'shame', 'listening'], 'bit'),
#  (['bit', 'disconnected,', 'listening', 'local'], 'shame'),
#  (['shame', 'bit', 'local', 'stations'], 'listening'),
#  (['listening', 'shame', 'stations', 'retro'], 'local'),
#  (['local', 'listening', 'retro', 'radio'], 'stations'),
#  (['stations', 'local', 'radio', 'added'], 'retro'),
#  (['retro', 'stations', 'added', 'overall'], 'radio'),
#  (['radio', 'retro', 'overall', 'atmosphere'], 'added'),
#  (['added', 'radio', 'atmosphere', 'greatly.staff'], 'overall'),
#  (['overall', 'added', 'greatly.staff', 'extremely'], 'atmosphere'),
#  (['atmosphere', 'overall', 'extremely', 'pleasant'], 'greatly.staff'),
#  (['greatly.staff', 'atmosphere', 'pleasant', 'stereotypically'], 'extremely'),
#  (['extremely', 'greatly.staff', 'stereotypically', 'efficient,'], 'pleasant'),
#  (['pleasant', 'extremely', 'efficient,', 'room'], 'stereotypically'),
#  (['stereotypically', 'pleasant', 'room', 'service'], 'efficient,'),
#  (['efficient,', 'stereotypically', 'service', 'carried'], 'room'),
#  (['room', 'efficient,', 'carried', 'exact'], 'service'),
#  (['service', 'room', 'exact', 'professionalism'], 'carried'),
#  (['carried', 'service', 'professionalism', 'experienced'], 'exact'),
#  (['exact', 'carried', 'experienced', 'quite'], 'professionalism'),
#  (['professionalism', 'exact', 'quite', 'galling'], 'experienced'),
#  (['experienced', 'professionalism', 'galling', 'charge,'], 'quite'),
#  (['quite', 'experienced', 'charge,', 'service'], 'galling'),
#  (['galling', 'quite', 'service', 'charge'], 'charge,'),
#  (['charge,', 'galling', 'charge', 'really'], 'service'),
#  (['service', 'charge,', 'really', 'set'], 'charge'),
#  (['charge', 'service', 'set', '10'], 'really'),
#  (['really', 'charge', '10', 'reviewers'], 'set'),
#  (['set', 'really', 'reviewers', 'right'], '10'),
#  (['10', 'set', 'right', 'say'], 'reviewers'),
#  (['reviewers', '10', 'say', 'heavy'], 'right'),
#  (['right', 'reviewers', 'heavy', 'smell'], 'say'),
#  (['say', 'right', 'smell', 'cigar'], 'heavy'),
#  (['heavy', 'say', 'cigar', 'smoke'], 'smell'),
#  (['smell', 'heavy', 'smoke', 'lobby'], 'cigar'),
#  (['cigar', 'smell', 'lobby', 'just'], 'smoke'),
#  (['smoke', 'cigar', 'just', 'quirky'], 'lobby'),
#  (['lobby', 'smoke', 'quirky', 'yesteryears'], 'just'),
#  (['just', 'lobby', 'yesteryears', 'feel'], 'quirky'),
#  (['quirky', 'just', 'feel', 'place.another'], 'yesteryears'),
#  (['yesteryears', 'quirky', 'place.another', 'major'], 'feel'),
#  (['feel', 'yesteryears', 'major', 'plus'], 'place.another'),
#  (['place.another', 'feel', 'plus', 'hotel'], 'major'),
#  (['major', 'place.another', 'hotel', 'fact'], 'plus'),
#  (['plus', 'major', 'fact', 'centrally'], 'hotel'),
#  (['hotel', 'plus', 'centrally', 'located'], 'fact'),
#  (['fact', 'hotel', 'located', 'zoological'], 'centrally'),
#  (['centrally', 'fact', 'zoological', 'garden'], 'located'),
#  (['located', 'centrally', 'garden', 'station'], 'zoological'),
#  (['zoological', 'located', 'station', 'just'], 'garden'),
#  (['garden', 'zoological', 'just', 'corner'], 'station'),
#  (['station', 'garden', 'corner', 'minutes'], 'just'),
#  (['just', 'station', 'minutes', 'away.all'], 'corner'),
#  (['corner', 'just', 'away.all', 'pretty'], 'minutes'),
#  (['minutes', 'corner', 'pretty', 'impressive'], 'away.all'),
#  (['away.all', 'minutes', 'impressive', 'luxurious'], 'pretty'),
#  (['pretty', 'away.all', 'luxurious', 'stay,'], 'impressive'),
#  (['impressive', 'pretty', 'stay,', 'not'], 'luxurious'),
#  (['luxurious', 'impressive', 'not', 'mind-blowingly'], 'stay,'),
#  (['stay,', 'luxurious', 'mind-blowingly', 'great'], 'not'),
#  (['not', 'stay,', 'great', 'certainly'], 'mind-blowingly'),
#  (['mind-blowingly', 'not', 'certainly', 'step'], 'great'),
#  (['great', 'mind-blowingly', 'step', 'hotels,'], 'certainly'),
#  (['truly', 'stunning', 'spot', 'right'], 'memorable'),
#  (['memorable', 'truly', 'right', 'beach'], 'spot'),
#  (['spot', 'memorable', 'beach', 'nusa'], 'right'),
#  (['right', 'spot', 'nusa', 'dua'], 'beach'),
#  (['beach', 'right', 'dua', 'stunning'], 'nusa'),
#  (['nusa', 'beach', 'stunning', 'views'], 'dua'),
#  (['dua', 'nusa', 'views', 'palm'], 'stunning'),
#  (['stunning', 'dua', 'palm', 'lined'], 'views'),
#  (['views', 'stunning', 'lined', 'ocean,'], 'palm'),
#  (['palm', 'views', 'ocean,', 'dinner'], 'lined'),
#  (['lined', 'palm', 'dinner', 'restaurant'], 'ocean,'),
#  (['ocean,', 'lined', 'restaurant', 'right'], 'dinner'),
#  (['dinner', 'ocean,', 'right', 'shore'], 'restaurant'),
#  (['restaurant', 'dinner', 'shore', 'wonderful'], 'right'),
#  (['right', 'restaurant', 'wonderful', 'way'], 'shore'),
#  (['shore', 'right', 'way', 'spend'], 'wonderful'),
#  (['wonderful', 'shore', 'spend', 'evening.from'], 'way'),
#  (['way', 'wonderful', 'evening.from', 'friendliness'], 'spend'),
#  (['spend', 'way', 'friendliness', 'helpfullness'], 'evening.from'),
#  (['evening.from', 'spend', 'helpfullness', 'staff'], 'friendliness'),
#  (['friendliness', 'evening.from', 'staff', 'central'], 'helpfullness'),
#  (['helpfullness', 'friendliness', 'central', 'pool'], 'staff'),
#  (['staff', 'helpfullness', 'pool', 'area'], 'central'),
#  (['central', 'staff', 'area', 'location'], 'pool'),
#  (['pool', 'central', 'location', 'just'], 'area'),
#  (['area', 'pool', 'just', 'right.located'], 'location'),
#  (['location', 'area', 'right.located', 'easy'], 'just'),
#  (['just', 'location', 'easy', 'walking'], 'right.located'),
#  (['right.located', 'just', 'walking', 'distance'], 'easy'),
#  (['easy', 'right.located', 'distance', 'local'], 'walking'),
#  (['walking', 'easy', 'local', 'restaurants'], 'distance'),
#  (['distance', 'walking', 'restaurants', 'shopping'], 'local'),
#  (['local', 'distance', 'shopping', 'westin'], 'restaurants'),
#  (['restaurants', 'local', 'westin', 'offered'], 'shopping'),
#  (['shopping', 'restaurants', 'offered', 'isolation'], 'westin'),
#  (['westin', 'shopping', 'isolation', 'constant'], 'offered'),
#  (['offered', 'westin', 'constant', 'hawkers'], 'isolation'),
#  (['isolation', 'offered', 'hawkers', 'need'], 'constant'),
#  (['constant', 'isolation', 'need', 'days'], 'hawkers'),
#  (['hawkers', 'constant', 'days', 'bali'], 'need'),
#  (['need', 'hawkers', 'bali', 'allowed'], 'days'),
#  (['days', 'need', 'allowed', 'access'], 'bali'),
#  (['bali', 'days', 'access', 'local'], 'allowed'),
#  (['allowed', 'bali', 'local', 'food'], 'access'),
#  (['access', 'allowed', 'food', 'shopping'], 'local'),
#  (['local', 'access', 'shopping', 'street'], 'food'),
#  (['food', 'local', 'street', 'opposed'], 'shopping'),
#  (['shopping', 'food', 'opposed', 'resort'], 'street'),
#  (['street', 'shopping', 'resort', 'prices.would'], 'opposed'),
#  (['opposed', 'street', 'prices.would', 'definitely'], 'resort'),
#  (['resort', 'opposed', 'definitely', 'stay,'], 'prices.would'),
#  (['business', 'solid', 'near', 'embassy'], 'hotel'),
#  (['hotel', 'business', 'embassy', 'stayed'], 'near'),
#  (['near', 'hotel', 'stayed', 'hotel'], 'embassy'),
#  (['embassy', 'near', 'hotel', 'okuras'], 'stayed'),
#  (['stayed', 'embassy', 'okuras', 'including'], 'hotel'),
#  (['hotel', 'stayed', 'including', 'kyoto'], 'okuras'),
#  (['okuras', 'hotel', 'kyoto', 'kobe,'], 'including'),
#  (['including', 'okuras', 'kobe,', 'great'], 'kyoto'),
#  (['kyoto', 'including', 'great', 'places'], 'kobe,'),
#  (['kobe,', 'kyoto', 'places', 'traveling'], 'great'),
#  (['great', 'kobe,', 'traveling', 'business'], 'places'),
#  (['places', 'great', 'business', 'man'], 'traveling'),
#  (['traveling', 'places', 'man', 'really'], 'business'),
#  (['business', 'traveling', 'really', 'know'], 'man'),
#  (['man', 'business', 'know', 'cater'], 'really'),
#  (['really', 'man', 'cater', 'needs'], 'know'),
#  (['know', 'really', 'needs', 'anticipate,'], 'cater'),
#  (['cater', 'know', 'anticipate,', 'tokyo'], 'needs'),
#  (['needs', 'cater', 'tokyo', 'hotel'], 'anticipate,'),
#  (['anticipate,', 'needs', 'hotel', 'especially'], 'tokyo'),
#  (['tokyo', 'anticipate,', 'especially', 'great'], 'hotel'),
#  (['hotel', 'tokyo', 'great', 'going'], 'especially'),
#  (['especially', 'hotel', 'going', 'government'], 'great'),
#  (['great', 'especially', 'government', 'business'], 'going'),
#  (['going', 'great', 'business', 'given'], 'government'),
#  (['government', 'going', 'given', 'nearness'], 'business'),
#  (['business', 'government', 'nearness', 'embassy,'], 'given'),
#  (['given', 'business', 'embassy,', 'good'], 'nearness'),
#  (['nearness', 'given', 'good', 'entertainment'], 'embassy,'),
#  (['embassy,', 'nearness', 'entertainment', 'biz'], 'good'),
#  (['good', 'embassy,', 'biz', 'main'], 'entertainment'),
#  (['entertainment', 'good', 'main', 'players'], 'biz'),
#  (['biz', 'entertainment', 'players', 'nearby'], 'main'),
#  (['main', 'biz', 'nearby', 'well.the'], 'players'),
#  (['players', 'main', 'well.the', 'rooms'], 'nearby'),
#  (['nearby', 'players', 'rooms', 'appointed'], 'well.the'),
#  (['well.the', 'nearby', 'appointed', 'need'], 'rooms'),
#  (['rooms', 'well.the', 'need', 'conduct'], 'appointed'),
#  (['appointed', 'rooms', 'conduct', 'business'], 'need'),
#  (['need', 'appointed', 'business', 'road,'], 'conduct'),
#  (['conduct', 'need', 'road,', 'special'], 'business'),
#  (['business', 'conduct', 'special', 'plans'], 'road,'),
#  (['road,', 'business', 'plans', 'help'], 'special'),
#  (['special', 'road,', 'help', 'eliminate'], 'plans'),
#  (['plans', 'special', 'eliminate', 'jet'], 'help'),
#  (['help', 'plans', 'jet', 'lag'], 'eliminate'),
#  (['eliminate', 'help', 'lag', 'best'], 'jet'),
#  (['jet', 'eliminate', 'best', 'dining'], 'lag'),
#  (['lag', 'jet', 'dining', 'hotel'], 'best'),
#  (['best', 'lag', 'hotel', 'tokyo'], 'dining'),
#  (['dining', 'best', 'tokyo', 'wide'], 'hotel'),
#  (['hotel', 'dining', 'wide', 'variety'], 'tokyo'),
#  (['tokyo', 'hotel', 'variety', 'choices,'], 'wide'),
#  (['place', 'nice', 'sure', 'lock'], 'make'),
#  (['make', 'place', 'lock', 'money'], 'sure'),
#  (['sure', 'make', 'money', 'warning'], 'lock'),
#  (['lock', 'sure', 'warning', 'money'], 'money'),
#  (['money', 'lock', 'money', 'valuables'], 'warning'),
#  (['warning', 'money', 'valuables', 'safe..'], 'money'),
#  (['money', 'warning', 'safe..', 'took'], 'valuables'),
#  (['valuables', 'money', 'took', 'large'], 'safe..'),
#  (['safe..', 'valuables', 'large', 'group'], 'took'),
#  (['took', 'safe..', 'group', 'rooms'], 'large'),
#  (['large', 'took', 'rooms', 'reserved'], 'group'),
#  (['group', 'large', 'reserved', 'rob'], 'rooms'),
#  (['rooms', 'group', 'rob', 'cash..'], 'reserved'),
#  (['reserved', 'rooms', 'cash..', 'mindful'], 'rob'),
#  (['rob', 'reserved', 'mindful', 'hate'], 'cash..'),
#  (['cash..', 'rob', 'hate', 'happen,'], 'mindful'),
#  (['mindful', 'cash..', 'happen,', 'resort'], 'hate'),
#  (['hate', 'mindful', 'resort', 'big'], 'happen,'),
#  (['happen,', 'hate', 'big', 'beautiful..'], 'resort'),
#  (['resort', 'happen,', 'beautiful..', 'hard'], 'big'),
#  (['big', 'resort', 'hard', 'place'], 'beautiful..'),
#  (['beautiful..', 'big', 'place', 'hurry'], 'hard'),
#  (['hard', 'beautiful..', 'hurry', 'vacation'], 'place'),
#  (['place', 'hard', 'vacation', 'people'], 'hurry'),
#  (['hurry', 'place', 'people', 'nice'], 'vacation'),
#  (['vacation', 'hurry', 'nice', 'gracious'], 'people'),
#  (['people', 'vacation', 'gracious', 'accommodating..'], 'nice'),
#  (['nice', 'people', 'accommodating..', 'took'], 'gracious'),
#  (['gracious', 'nice', 'took', 'tip'], 'accommodating..'),
#  (['accommodating..', 'gracious', 'tip', 'reviewer'], 'took'),
#  (['took', 'accommodating..', 'reviewer', 'going'], 'tip'),
#  (['tip', 'took', 'going', 'bring'], 'reviewer'),
#  (['reviewer', 'tip', 'bring', '100.00'], 'going'),
#  (['going', 'reviewer', '100.00', 'worth'], 'bring'),
#  (['bring', 'going', 'worth', '1,'], '100.00'),
#  (['100.00', 'bring', '1,', 'really'], 'worth'),
#  (['worth', '100.00', 'really', 'came'], '1,'),
#  (['1,', 'worth', 'came', 'handy'], 'really'),
#  (['really', '1,', 'handy', 'giving'], 'came'),
#  (['came', 'really', 'giving', 'tips,'], 'handy'),
#  (['hotel', 'good', 'kids', 'weekend'], 'crowded'),
#  (['crowded', 'hotel', 'weekend', 'review'], 'kids'),
#  (['kids', 'crowded', 'review', 'like'], 'weekend'),
#  (['weekend', 'kids', 'like', 'good'], 'review'),
#  (['review', 'weekend', 'good', 'hotel.-'], 'like'),
#  (['like', 'review', 'hotel.-', 'staff'], 'good'),
#  (['good', 'like', 'staff', 'friendly-'], 'hotel.-'),
#  (['hotel.-', 'good', 'friendly-', 'rooms'], 'staff'),
#  (['staff', 'hotel.-', 'rooms', 'comfortable'], 'friendly-'),
#  (['friendly-', 'staff', 'comfortable', 'nicely'], 'rooms'),
#  (['rooms', 'friendly-', 'nicely', 'furnished-'], 'comfortable'),
#  (['comfortable', 'rooms', 'furnished-', 'location'], 'nicely'),
#  (['nicely', 'comfortable', 'location', 'good'], 'furnished-'),
#  (['furnished-', 'nicely', 'good', 'especially'], 'location'),
#  (['location', 'furnished-', 'especially', 'need'], 'good'),
#  (['good', 'location', 'need', 'near'], 'especially'),
#  (['especially', 'good', 'near', 'airportkeep'], 'need'),
#  (['need', 'especially', 'airportkeep', 'mind'], 'near'),
#  (['near', 'need', 'mind', 'wife'], 'airportkeep'),
#  (['airportkeep', 'near', 'wife', 'son'], 'mind'),
#  (['mind', 'airportkeep', 'son', '18'], 'wife'),
#  (['wife', 'mind', '18', 'years'], 'son'),
#  (['son', 'wife', 'years', 'old'], '18'),
#  (['18', 'son', 'old', 'recent'], 'years'),
#  (['years', '18', 'recent', 'weekend'], 'old'),
#  (['old', 'years', 'weekend', 'place'], 'recent'),
#  (['recent', 'old', 'place', 'packed'], 'weekend'),
#  (['weekend', 'recent', 'packed', 'kids'], 'place'),
#  (['place', 'weekend', 'kids', 'seemingly'], 'packed'),
#  (['packed', 'place', 'seemingly', 'hockey'], 'kids'),
#  (['kids', 'packed', 'hockey', 'tournaments'], 'seemingly'),
#  (['seemingly', 'kids', 'tournaments', 'taking'], 'hockey'),
#  (['hockey', 'seemingly', 'taking', 'place'], 'tournaments'),
#  (['tournaments', 'hockey', 'place', 'time,'], 'taking'),
#  (['taking', 'tournaments', 'time,', 'issue'], 'place'),
#  (['place', 'taking', 'issue', 'eating'], 'time,'),
#  (['time,', 'place', 'eating', 'breakfast'], 'issue'),
#  (['issue', 'time,', 'breakfast', 'small'], 'eating'),
#  (['eating', 'issue', 'small', 'room'], 'breakfast'),
#  (['breakfast', 'eating', 'room', 'jam-packed'], 'small'),
#  (['small', 'breakfast', 'jam-packed', 'wanted'], 'room'),
#  (['room', 'small', 'wanted', 'leisurely'], 'jam-packed'),
#  (['jam-packed', 'room', 'leisurely', 'quiet'], 'wanted'),
#  (['wanted', 'jam-packed', 'quiet', 'swim'], 'leisurely'),
#  (['leisurely', 'wanted', 'swim', 'pool'], 'quiet'),
#  (['quiet', 'leisurely', 'pool', 'hot'], 'swim'),
#  (['swim', 'quiet', 'hot', 'tub'], 'pool'),
#  (['pool', 'swim', 'tub', "n't"], 'hot'),
#  (['hot', 'pool', "n't", 'going'], 'tub'),
#  (['tub', 'hot', 'going', 'happen'], "n't"),
#  (["n't", 'tub', 'happen', 'bunch'], 'going'),
#  (['going', "n't", 'bunch', '10'], 'happen'),
#  (['happen', 'going', '10', '12'], 'bunch'),
#  (['bunch', 'happen', '12', 'year'], '10'),
#  (['10', 'bunch', 'year', 'old'], '12'),
#  (['12', '10', 'old', 'boys,'], 'year'),
#  (['year', '12', 'boys,', 'enjoyed'], 'old'),
#  (['old', 'year', 'enjoyed', 'stay,'], 'boys,'),
#  (['hotel', 'good', 'arrived', 'hotel'], 'overrated'),
#  (['overrated', 'hotel', 'hotel', 'check-in'], 'arrived'),
#  (['arrived', 'overrated', 'check-in', 'time'], 'hotel'),
#  (['hotel', 'arrived', 'time', 'told'], 'check-in'),
#  (['check-in', 'hotel', 'told', 'did'], 'time'),
#  (['time', 'check-in', 'did', "n't"], 'told'),
#  (['told', 'time', "n't", 'room'], 'did'),
#  (['did', 'told', 'room', 'ready,'], "n't"),
#  (["n't", 'did', 'ready,', 'asked'], 'room'),
#  (['room', "n't", 'asked', 'wait'], 'ready,'),
#  (['ready,', 'room', 'wait', 'hour'], 'asked'),
#  (['asked', 'ready,', 'hour', 'said'], 'wait'),
#  (['wait', 'asked', 'said', 'come'], 'hour'),
#  (['hour', 'wait', 'come', 'seek'], 'said'),
#  (['said', 'hour', 'seek', 'sitting'], 'come'),
#  (['come', 'said', 'sitting', 'area'], 'seek'),
#  (['seek', 'come', 'area', 'ready,'], 'sitting'),
#  (['sitting', 'seek', 'ready,', 'did'], 'area'),
#  (['area', 'sitting', 'did', "n't"], 'ready,'),
#  (['ready,', 'area', "n't", 'come'], 'did'),
#  (['did', 'ready,', 'come', 'ask,'], "n't"),
#  (["n't", 'did', 'ask,', 'apologetic.the'], 'come'),
#  (['come', "n't", 'apologetic.the', 'lobby'], 'ask,'),
#  (['ask,', 'come', 'lobby', 'area'], 'apologetic.the'),
#  (['apologetic.the', 'ask,', 'area', 'nice'], 'lobby'),
#  (['lobby', 'apologetic.the', 'nice', 'no'], 'area'),
#  (['area', 'lobby', 'no', 'way'], 'nice'),
#  (['nice', 'area', 'way', 'reflected'], 'no'),
#  (['no', 'nice', 'reflected', 'quality'], 'way'),
#  (['way', 'no', 'quality', 'room,'], 'reflected'),
#  (['reflected', 'way', 'room,', 'room'], 'quality'),
#  (['quality', 'reflected', 'room', 'stayed'], 'room,'),
#  (['room,', 'quality', 'stayed', 'lower'], 'room'),
#  (['room', 'room,', 'lower', 'floor'], 'stayed'),
#  (['stayed', 'room', 'floor', 'looked'], 'lower'),
#  (['lower', 'stayed', 'looked', 'street'], 'floor'),
#  (['floor', 'lower', 'street', 'courtyard'], 'looked'),
#  (['looked', 'floor', 'courtyard', 'service'], 'street'),
#  (['street', 'looked', 'service', 'entrance'], 'courtyard'),
#  (['courtyard', 'street', 'entrance', 'hotel'], 'service'),
#  (['service', 'courtyard', 'hotel', 'employees'], 'entrance'),
#  (['entrance', 'service', 'employees', 'took'], 'hotel'),
#  (['hotel', 'entrance', 'took', 'cigarette'], 'employees'),
#  (['employees', 'hotel', 'cigarette', 'breaks,'], 'took'),
#  (['took', 'employees', 'breaks,', 'room'], 'cigarette'),
#  (['cigarette', 'took', 'room', 'dated,'], 'breaks,'),
#  (['breaks,', 'cigarette', 'dated,', 'initial'], 'room'),
#  (['room', 'breaks,', 'initial', 'impression'], 'dated,'),
#  (['dated,', 'room', 'impression', 'eerily'], 'initial'),
#  (['initial', 'dated,', 'eerily', 'similar'], 'impression'),
#  (['impression', 'initial', 'similar', 'rooms'], 'eerily'),
#  (['eerily', 'impression', 'rooms', 'holiday'], 'similar'),
#  (['similar', 'eerily', 'holiday', 'inns,'], 'rooms'),
#  (['rooms', 'similar', 'inns,', 'beds'], 'holiday'),
#  (['holiday', 'rooms', 'beds', 'better'], 'inns,'),
#  (['inns,', 'holiday', 'better', 'holiday'], 'beds'),
#  (['beds', 'inns,', 'holiday', 'inns'], 'better'),
#  (['better', 'beds', 'inns', 'certainly'], 'holiday'),
#  (['holiday', 'better', 'certainly', 'not'], 'inns'),
#  (['inns', 'holiday', 'not', 'star'], 'certainly'),
#  (['certainly', 'inns', 'star', 'quality,'], 'not'),
#  (['not', 'certainly', 'quality,', 'bathroom'], 'star'),
#  (['star', 'not', 'bathroom', 'dated,'], 'quality,'),
#  (['quality,', 'star', 'dated,', 'redeeming'], 'bathroom'),
#  (['bathroom', 'quality,', 'redeeming', 'equipped'], 'dated,'),
#  (['dated,', 'bathroom', 'equipped', 'great'], 'redeeming'),
#  (['redeeming', 'dated,', 'great', 'shower'], 'equipped'),
#  (['equipped', 'redeeming', 'shower', 'awesome'], 'great'),
#  (['great', 'equipped', 'awesome', 'water'], 'shower'),
#  (['shower', 'great', 'water', 'pressure'], 'awesome'),
#  (['awesome', 'shower', 'pressure', 'hotel'], 'water'),
#  (['water', 'awesome', 'hotel', 'close'], 'pressure'),
#  (['pressure', 'water', 'close', 'main'], 'hotel'),
#  (['hotel', 'pressure', 'main', 'train'], 'close'),
#  (['close', 'hotel', 'train', 'station'], 'main'),
#  (['main', 'close', 'station', 'walking'], 'train'),
#  (['train', 'main', 'walking', 'distance'], 'station'),
#  (['station', 'train', 'distance', 'tourist'], 'walking'),
#  (['walking', 'station', 'tourist', 'sites,'], 'distance'),
#  (['distance', 'walking', 'sites,', 'shops'], 'tourist'),
#  (['tourist', 'distance', 'shops', 'nearby'], 'sites,'),
#  (['sites,', 'tourist', 'nearby', 'internet'], 'shops'),
#  (['shops', 'sites,', 'internet', 'cafe'], 'nearby'),
#  (['nearby', 'shops', 'cafe', 'street,'], 'internet'),
#  (['internet', 'nearby', 'street,', 'nearby'], 'cafe'),
#  (['cafe', 'internet', 'nearby', 'street'], 'street,'),
#  (['street,', 'cafe', 'street', 'restaurants'], 'nearby'),
#  (['nearby', 'street,', 'restaurants', 'open'], 'street'),
#  (['street', 'nearby', 'open', 'late'], 'restaurants'),
#  (['restaurants', 'street', 'late', 'night'], 'open'),
#  (['open', 'restaurants', 'night', 'bk'], 'late'),
#  (['late', 'open', 'bk', 'mcdonald'], 'night'),
#  (['night', 'late', 'mcdonald', 'nearby'], 'bk'),
#  (['bk', 'night', 'nearby', 'forget'], 'mcdonald'),
#  (['mcdonald', 'bk', 'forget', "n't"], 'nearby'),
#  (['nearby', 'mcdonald', "n't", 'use'], 'forget'),
#  (['forget', 'nearby', 'use', 'gym'], "n't"),
#  (["n't", 'forget', 'gym', 'extra'], 'use'),
#  (['use', "n't", 'extra', 'charge,'], 'gym'),
#  (['gym', 'use', 'charge,', 'did'], 'extra'),
#  (['extra', 'gym', 'did', "n't"], 'charge,'),
#  (['charge,', 'extra', "n't", 'try'], 'did'),
#  (['did', 'charge,', 'try', 'restaurant,'], "n't"),
#  (["n't", 'did', 'restaurant,', 'try'], 'try'),
#  (['try', "n't", 'try', 'hotel'], 'restaurant,'),
#  (['restaurant,', 'try', 'hotel', 'amsterdam,'], 'try'),
#  (['not', 'okay', 'checking', 'price'], 'fantastic,'),
#  (['fantastic,', 'not', 'price', 'upscale'], 'checking'),
#  (['checking', 'fantastic,', 'upscale', 'hotels'], 'price'),
#  (['price', 'checking', 'hotels', 'phoenix'], 'upscale'),
#  (['upscale', 'price', 'phoenix', 'scottsdale'], 'hotels'),
#  (['hotels', 'upscale', 'scottsdale', 'decided'], 'phoenix'),
#  (['phoenix', 'hotels', 'decided', 'stay'], 'scottsdale'),
#  (['scottsdale', 'phoenix', 'stay', 'biltmore.overall'], 'decided'),
#  (['decided', 'scottsdale', 'biltmore.overall', 'trip'], 'stay'),
#  (['stay', 'decided', 'trip', 'pleasant'], 'biltmore.overall'),
#  (['biltmore.overall', 'stay', 'pleasant', 'discounted'], 'trip'),
#  (['trip', 'biltmore.overall', 'discounted', 'summer'], 'pleasant'),
#  (['pleasant', 'trip', 'summer', 'rate'], 'discounted'),
#  (['discounted', 'pleasant', 'rate', 'reasonable,'], 'summer'),
#  (['summer', 'discounted', 'reasonable,', 'line'], 'rate'),
#  (['rate', 'summer', 'line', 'hotel'], 'reasonable,'),
#  (['reasonable,', 'rate', 'hotel', 'little'], 'line'),
#  (['line', 'reasonable,', 'little', 'inconsistencies'], 'hotel'),
#  (['hotel', 'line', 'inconsistencies', 'want'], 'little'),
#  (['little', 'hotel', 'want', 'return'], 'inconsistencies'),
#  (['inconsistencies', 'little', 'return', 'again.for'], 'want'),
#  (['want', 'inconsistencies', 'again.for', 'example'], 'return'),
#  (['return', 'want', 'example', 'check'], 'again.for'),
#  (['again.for', 'return', 'check', 'helped'], 'example'),
#  (['example', 'again.for', 'helped', 'warm'], 'check'),
#  (['check', 'example', 'warm', 'dwelcoming'], 'helped'),
#  (['helped', 'check', 'dwelcoming', 'gentleman,'], 'warm'),
#  (['warm', 'helped', 'gentleman,', 'requested'], 'dwelcoming'),
#  (['dwelcoming', 'warm', 'requested', 'late'], 'gentleman,'),
#  (['gentleman,', 'dwelcoming', 'late', 'check'], 'requested'),
#  (['requested', 'gentleman,', 'check', 'women'], 'late'),
#  (['late', 'requested', 'women', 'desk'], 'check'),
#  (['check', 'late', 'desk', 'seemd'], 'women'),
#  (['women', 'check', 'seemd', 'unhappy'], 'desk'),
#  (['desk', 'women', 'unhappy', 'did'], 'seemd'),
#  (['seemd', 'desk', 'did', 'not'], 'unhappy'),
#  (['unhappy', 'seemd', 'not', 'smile,'], 'did'),
#  (['did', 'unhappy', 'smile,', 'rooms'], 'not'),
#  (['not', 'did', 'rooms', 'bit'], 'smile,'),
#  (['smile,', 'not', 'bit', 'dissapointing,'], 'rooms'),
#  (['rooms', 'smile,', 'dissapointing,', 'requested'], 'bit'),
#  (['bit', 'rooms', 'requested', 'room'], 'dissapointing,'),
#  (['dissapointing,', 'bit', 'room', 'king'], 'requested'),
#  (['requested', 'dissapointing,', 'king', 'smoking'], 'room'),
#  (['room', 'requested', 'smoking', 'not'], 'king'),
#  (['king', 'room', 'not', 'available'], 'smoking'),
#  (['smoking', 'king', 'available', 'offered'], 'not'),
#  (['not', 'smoking', 'offered', 'double'], 'available'),
#  (['available', 'not', 'double', 'smoking'], 'offered'),
#  (['offered', 'available', 'smoking', 'apatio,'], 'double'),
#  (['double', 'offered', 'apatio,', 'happy'], 'smoking'),
#  (['smoking', 'double', 'happy', 'upgrade'], 'apatio,'),
#  (['apatio,', 'smoking', 'upgrade', 'paid'], 'happy'),
#  (['happy', 'apatio,', 'paid', 'dissapointed,'], 'upgrade'),
#  (['upgrade', 'happy', 'dissapointed,', 'no'], 'paid'),
#  (['paid', 'upgrade', 'no', 'privacy'], 'dissapointed,'),
#  (['dissapointed,', 'paid', 'privacy', 'walk'], 'no'),
#  (['no', 'dissapointed,', 'walk', 'balcony'], 'privacy'),
#  (['privacy', 'no', 'balcony', 'balcony,'], 'walk'),
#  (['walk', 'privacy', 'balcony,', 'corner'], 'balcony'),
#  (['balcony', 'walk', 'corner', 'balcony'], 'balcony,'),
#  (['balcony,', 'balcony', 'balcony', 'totally'], 'corner'),
#  (['corner', 'balcony,', 'totally', 'covered'], 'balcony'),
#  (['balcony', 'corner', 'covered', 'trees'], 'totally'),
#  (['totally', 'balcony', 'trees', 'absolutely'], 'covered'),
#  (['covered', 'totally', 'absolutely', 'no'], 'trees'),
#  (['trees', 'covered', 'no', 'view'], 'absolutely'),
#  (['absolutely', 'trees', 'view', 'it.the'], 'no'),
#  (['no', 'absolutely', 'it.the', 'inconsistencies'], 'view'),
#  (['view', 'no', 'inconsistencies', 'countinued'], 'it.the'),
#  (['it.the', 'view', 'countinued', 'quality'], 'inconsistencies'),
#  (['inconsistencies', 'it.the', 'quality', 'property,'], 'countinued'),
#  (['countinued', 'inconsistencies', 'property,', 'main'], 'quality'),
#  (['quality', 'countinued', 'main', 'pool'], 'property,'),
#  (['property,', 'quality', 'pool', 'area'], 'main'),
#  (['main', 'property,', 'area', 'clean'], 'pool'),
#  (['pool', 'main', 'clean', 'way'], 'area'),
#  (['area', 'pool', 'way', 'crowded,'], 'clean'),
#  (['clean', 'area', 'crowded,', '2nd'], 'way'),
#  (['way', 'clean', '2nd', 'largest'], 'crowded,'),
#  (['crowded,', 'way', 'largest', 'pool'], '2nd'),
#  (['2nd', 'crowded,', 'pool', 'area'], 'largest'),
#  (['largest', '2nd', 'area', 'better'], 'pool'),
#  (['pool', 'largest', 'better', 'choice'], 'area'),
#  (['area', 'pool', 'choice', 'offered'], 'better'),
#  (['better', 'area', 'offered', 'child'], 'choice'),
#  (['choice', 'better', 'child', 'pool'], 'offered'),
#  (['offered', 'choice', 'pool', 'adult'], 'child'),
#  (['child', 'offered', 'adult', 'pool'], 'pool'),
#  (['pool', 'child', 'pool', 'apeaceful'], 'adult'),
#  (['adult', 'pool', 'apeaceful', 'setting,'], 'pool'),
#  (['pool', 'adult', 'setting,', 'ventured'], 'apeaceful'),
#  (['apeaceful', 'pool', 'ventured', 'smaller'], 'setting,'),
#  (['setting,', 'apeaceful', 'smaller', 'pools'], 'ventured'),
#  (['ventured', 'setting,', 'pools', 'came'], 'smaller'),
#  (['smaller', 'ventured', 'came', 'slimey'], 'pools'),
#  (['pools', 'smaller', 'slimey', 'pools'], 'came'),
#  (['came', 'pools', 'pools', 'towels,'], 'slimey'),
#  (['slimey', 'came', 'towels,', 'not'], 'pools'),
#  (['pools', 'slimey', 'not', 'worth'], 'towels,'),
#  (['towels,', 'pools', 'worth', 'search.the'], 'not'),
#  (['not', 'towels,', 'search.the', 'biggest'], 'worth'),
#  (['worth', 'not', 'biggest', 'rip'], 'search.the'),
#  (['search.the', 'worth', 'rip', 'food,'], 'biggest'),
#  (['biggest', 'search.the', 'food,', 'ate'], 'rip'),
#  (['rip', 'biggest', 'ate', 'times'], 'food,'),
#  (['food,', 'rip', 'times', 'did'], 'ate'),
#  (['ate', 'food,', 'did', 'not'], 'times'),
#  (['times', 'ate', 'not', 'car'], 'did'),
#  (['did', 'times', 'car', 'not'], 'not'),
#  (['not', 'did', 'not', 'worth'], 'car'),
#  (['car', 'not', 'worth', 'price,'], 'not'),
#  (['not', 'car', 'price,', "n't"], 'worth'),
#  (['worth', 'not', "n't", 'eat'], 'price,'),
#  (['price,', 'worth', 'eat', 'unless'], "n't"),
#  (["n't", 'price,', 'unless', 'too.overally'], 'eat'),
#  (['eat', "n't", 'too.overally', 'fun'], 'unless'),
#  (['unless', 'eat', 'fun', "n't"], 'too.overally'),
#  (['too.overally', 'unless', "n't", 'necessarily'], 'fun'),
#  (['fun', 'too.overally', 'necessarily', 'recoomend'], "n't"),
#  (["n't", 'fun', 'recoomend', 'hotel'], 'necessarily'),
#  (['necessarily', "n't", 'hotel', 'unless'], 'recoomend'),
#  (['recoomend', 'necessarily', 'unless', 'looking'], 'hotel'),
#  (['hotel', 'recoomend', 'looking', 'cheapest'], 'unless'),
#  (['unless', 'hotel', 'cheapest', 'star'], 'looking'),
#  (['looking', 'unless', 'star', 'hotels'], 'cheapest'),
#  (['cheapest', 'looking', 'hotels', 'booked'], 'star'),
#  (['star', 'cheapest', 'booked', 'fantastic'], 'hotels'),
#  (['hotels', 'star', 'fantastic', 'deal,'], 'booked'),
#  (['beautiful', 'resort', 'ends', 'just'], 'thats'),
#  (['thats', 'beautiful', 'just', 'returned'], 'ends'),
#  (['ends', 'thats', 'returned', '5'], 'just'),
#  (['just', 'ends', '5', 'day'], 'returned'),
#  (['returned', 'just', 'day', 'stay'], '5'),
#  (['5', 'returned', 'stay', 'majestic'], 'day'),
#  (['day', '5', 'majestic', 'glad'], 'stay'),
#  (['stay', 'day', 'glad', "n't"], 'majestic'),
#  (['majestic', 'stay', "n't", 'usual'], 'glad'),
#  (['glad', 'majestic', 'usual', '7'], "n't"),
#  (["n't", 'glad', '7', 'day'], 'usual'),
#  (['usual', "n't", 'day', 'stay'], '7'),
#  (['7', 'usual', 'stay', 'ready'], 'day'),
#  (['day', '7', 'ready', 'come'], 'stay'),
#  (['stay', 'day', 'come', 'home'], 'ready'),
#  (['ready', 'stay', 'home', '4th'], 'come'),
#  (['come', 'ready', '4th', 'night.the'], 'home'),
#  (['home', 'come', 'night.the', 'property'], '4th'),
#  (['4th', 'home', 'property', 'gorgeus'], 'night.the'),
#  (['night.the', '4th', 'gorgeus', 'staff'], 'property'),
#  (['property', 'night.the', 'staff', 'friendly'], 'gorgeus'),
#  (['gorgeus', 'property', 'friendly', 'rooms'], 'staff'),
#  (['staff', 'gorgeus', 'rooms', 'clean'], 'friendly'),
#  (['friendly', 'staff', 'clean', 'bed'], 'rooms'),
#  (['rooms', 'friendly', 'bed', 'horrific'], 'clean'),
#  (['clean', 'rooms', 'horrific', 'asked'], 'bed'),
#  (['bed', 'clean', 'asked', 'mattress'], 'horrific'),
#  (['horrific', 'bed', 'mattress', 'topper'], 'asked'),
#  (['asked', 'horrific', 'topper', 'appeared'], 'mattress'),
#  (['mattress', 'asked', 'appeared', 'water'], 'topper'),
#  (['topper', 'mattress', 'water', 'pool'], 'appeared'),
#  (['appeared', 'topper', 'pool', 'beautiful,'], 'water'),
#  (['water', 'appeared', 'beautiful,', 'time'], 'pool'),
#  (['pool', 'water', 'time', 'ai'], 'beautiful,'),
#  (['beautiful,', 'pool', 'ai', 'sway'], 'time'),
#  (['time', 'beautiful,', 'sway', 'try'], 'ai'),
#  (['ai', 'time', 'try', 'again.i'], 'sway'),
#  (['sway', 'ai', 'again.i', 'follow'], 'try'),
#  (['try', 'sway', 'follow', 'motto'], 'again.i'),
#  (['again.i', 'try', 'motto', 'pay,'], 'follow'),
#  (['follow', 'again.i', 'pay,', 'house'], 'motto'),
#  (['motto', 'follow', 'house', 'wines'], 'pay,'),
#  (['pay,', 'motto', 'wines', 'awful'], 'house'),
#  (['house', 'pay,', 'awful', 'tasted'], 'wines'),
#  (['wines', 'house', 'tasted', 'horrible'], 'awful'),
#  (['awful', 'wines', 'horrible', 'margarita'], 'tasted'),
#  (['tasted', 'awful', 'margarita', 'life,'], 'horrible'),
#  (['horrible', 'tasted', 'life,', 'ca'], 'margarita'),
#  (['margarita', 'horrible', 'ca', "n't"], 'life,'),
#  (['life,', 'margarita', "n't", 'beleive'], 'ca'),
#  (['ca', 'life,', 'beleive', 'people'], "n't"),
#  (["n't", 'ca', 'people', 'actually'], 'beleive'),
#  (['beleive', "n't", 'actually', 'thought'], 'people'),
#  (['people', 'beleive', 'thought', 'food'], 'actually'),
#  (['actually', 'people', 'food', 'edible,'], 'thought'),
#  (['thought', 'actually', 'edible,', 'breakfast'], 'food'),
#  (['food', 'thought', 'breakfast', 'best'], 'edible,'),
#  (['edible,', 'food', 'best', 'safest'], 'breakfast'),
#  (['breakfast', 'edible,', 'safest', 'meal'], 'best'),
#  (['best', 'breakfast', 'meal', 'goes'], 'safest'),
#  (['safest', 'best', 'goes', 'far,'], 'meal'),
#  (['meal', 'safest', 'far,', 'not'], 'goes'),
#  (['goes', 'meal', 'not', 'great'], 'far,'),
#  (['far,', 'goes', 'great', 'group'], 'not'),
#  (['not', 'far,', 'group', 'people'], 'great'),
#  (['great', 'not', 'people', 'large'], 'group'),
#  (['group', 'great', 'large', 'group'], 'people'),
#  (['people', 'group', 'group', 'definitely'], 'large'),
#  (['large', 'people', 'definitely', 'not'], 'group'),
#  (['group', 'large', 'not', 'enjoyed'], 'definitely'),
#  (['definitely', 'group', 'enjoyed', 'time'], 'not'),
#  (['not', 'definitely', 'time', 'did,'], 'enjoyed'),
#  (['enjoyed', 'not', 'did,', 'did'], 'time'),
#  (['time', 'enjoyed', 'did', 'not'], 'did,'),
#  (['did,', 'time', 'not', 'sick'], 'did'),
#  (['did', 'did,', 'sick', 'did'], 'not'),
#  (['not', 'did', 'did', 'not'], 'sick'),
#  (['sick', 'not', 'not', 'eat'], 'did'),
#  (['did', 'sick', 'eat', 'salad'], 'not'),
#  (['not', 'did', 'salad', 'brushed'], 'eat'),
#  (['eat', 'not', 'brushed', 'teeth'], 'salad'),
#  (['salad', 'eat', 'teeth', 'bottled'], 'brushed'),
#  (['brushed', 'salad', 'bottled', 'water'], 'teeth'),
#  (['teeth', 'brushed', 'water', 'took'], 'bottled'),
#  (['bottled', 'teeth', 'took', 'pepto'], 'water'),
#  (['water', 'bottled', 'pepto', '3'], 'took'),
#  (['took', 'water', '3', 'days'], 'pepto'),
#  (['pepto', 'took', 'days', 'time,'], '3'),
#  (['3', 'pepto', 'time,', 'sadly'], 'days'),
#  (['days', '3', 'sadly', 'friends'], 'time,'),
#  (['time,', 'days', 'friends', 'leaving'], 'sadly'),
#  (['sadly', 'time,', 'leaving', 'teenager'], 'friends'),
#  (['friends', 'sadly', 'teenager', 'hospital'], 'leaving'),
#  (['leaving', 'friends', 'hospital', 'did'], 'teenager'),
#  (['teenager', 'leaving', 'did', 'not'], 'hospital'),
#  (['hospital', 'teenager', 'not', 'return'], 'did'),
#  (['did', 'hospital', 'return', 'till'], 'not'),
#  (['not', 'did', 'till', '3'], 'return'),
#  (['return', 'not', '3', 'days'], 'till'),
#  (['till', 'return', 'days', 'later,'], '3'),
#  (['3', 'till', 'later,', 'majestic'], 'days'),
#  (['days', '3', 'majestic', 'colonial'], 'later,'),
#  (['later,', 'days', 'colonial', 'no'], 'majestic'),
#  (['majestic', 'later,', 'no', 'rooms'], 'colonial'),
#  (['colonial', 'majestic', 'rooms', 'available'], 'no'),
#  (['no', 'colonial', 'available', 'no'], 'rooms'),
#  (['rooms', 'no', 'no', 'effort'], 'available'),
#  (['available', 'rooms', 'effort', 'help'], 'no'),
#  (['no', 'available', 'help', 'slept'], 'effort'),
#  (['effort', 'no', 'slept', 'hospital'], 'help'),
#  (['help', 'effort', 'hospital', '2'], 'slept'),
#  (['slept', 'help', '2', 'nights,'], 'hospital'),
#  (['hospital', 'slept', 'nights,', 'husband'], '2'),
#  (['2', 'hospital', 'husband', 'survived'], 'nights,'),
#  (['nights,', '2', 'survived', 'time'], 'husband'),
#  (['husband', 'nights,', 'time', 'sick'], 'survived'),
#  (['survived', 'husband', 'sick', 'home,'], 'time'),
#  (['time', 'survived', 'home,', 'crap'], 'sick'),
#  (['sick', 'time', 'crap', 'shoot,'], 'home,'),
#  (['choice', 'good', 'traveller', 'recently'], 'solo'),
#  (['solo', 'choice', 'recently', 'stayed'], 'traveller'),
#  (['traveller', 'solo', 'stayed', '4'], 'recently'),
#  (['recently', 'traveller', '4', 'nights'], 'stayed'),
#  (['stayed', 'recently', 'nights', 'highly'], '4'),
#  (['4', 'stayed', 'highly', 'recommend'], 'nights'),
#  (['nights', '4', 'recommend', 'hotel,'], 'highly'),
#  (['highly', 'nights', 'hotel,', 'location'], 'recommend'),
#  (['recommend', 'highly', 'location', 'fantastic'], 'hotel,'),
#  (['hotel,', 'recommend', 'fantastic', 'right'], 'location'),
#  (['location', 'hotel,', 'right', 'train'], 'fantastic'),
#  (['fantastic', 'location', 'train', 'station'], 'right'),
#  (['right', 'fantastic', 'station', 'walking'], 'train'),
#  (['train', 'right', 'walking', 'distance'], 'station'),
#  (['station', 'train', 'distance', 'major'], 'walking'),
#  (['walking', 'station', 'major', 'sights'], 'distance'),
#  (['distance', 'walking', 'sights', 'restaurants/cafes,'], 'major'),
#  (['major', 'distance', 'restaurants/cafes,', 'room'], 'sights'),
#  (['sights', 'major', 'room', 'comfortable'], 'restaurants/cafes,'),
#  (['restaurants/cafes,', 'sights', 'comfortable', 'little'], 'room'),
#  (['room', 'restaurants/cafes,', 'little', 'warm'], 'comfortable'),
#  (['comfortable', 'room', 'warm', 'liking,'], 'little'),
#  (['little', 'comfortable', 'liking,', 'bathroom'], 'warm'),
#  (['warm', 'little', 'bathroom', 'spacious'], 'liking,'),
#  (['liking,', 'warm', 'spacious', 'great'], 'bathroom'),
#  (['bathroom', 'liking,', 'great', 'shower,'], 'spacious'),
#  (['spacious', 'bathroom', 'shower,', 'did'], 'great'),
#  (['great', 'spacious', 'did', "n't"], 'shower,'),
#  (['shower,', 'great', "n't", 'eat'], 'did'),
#  (['did', 'shower,', 'eat', 'ca'], "n't"),
#  (["n't", 'did', 'ca', "n't"], 'eat'),
#  (['eat', "n't", "n't", 'comment'], 'ca'),
#  (['ca', 'eat', 'comment', 'food,'], "n't"),
#  (["n't", 'ca', 'food,', 'things'], 'comment'),
#  (['comment', "n't", 'things', 'did'], 'food,'),
#  (['food,', 'comment', 'did', "n't"], 'things'),
#  (['things', 'food,', "n't", 'like'], 'did'),
#  (['did', 'things', 'like', 'lack'], "n't"),
#  (["n't", 'did', 'lack', 'tea/coffee'], 'like'),
#  (['like', "n't", 'tea/coffee', 'making'], 'lack'),
#  (['lack', 'like', 'making', 'facilites'], 'tea/coffee'),
#  (['tea/coffee', 'lack', 'facilites', 'english'], 'making'),
#  (['making', 'tea/coffee', 'english', 'language'], 'facilites'),
#  (['facilites', 'making', 'language', 'tv'], 'english'),
#  (['english', 'facilites', 'tv', 'channels,'], 'language'),
#  (['not', 'room/casino', 'relaxing', 'short'], 'just'),
#  (['just', 'not', 'short', 'trip'], 'relaxing'),
#  (['relaxing', 'just', 'trip', '4'], 'short'),
#  (['short', 'relaxing', '4', 'nights'], 'trip'),
#  (['trip', 'short', 'nights', '5'], '4'),
#  (['4', 'trip', '5', 'days'], 'nights'),
#  (['nights', '4', 'days', 'breezes'], '5'),
#  (['5', 'nights', 'breezes', 'superclub'], 'days'),
#  (['days', '5', 'superclub', 'hotel'], 'breezes'),
#  (['breezes', 'days', 'hotel', 'casino'], 'superclub'),
#  (['superclub', 'breezes', 'casino', 'punta'], 'hotel'),
#  (['hotel', 'superclub', 'punta', 'cana'], 'casino'),
#  (['casino', 'hotel', 'cana', 'feb.9-13'], 'punta'),
#  (['punta', 'casino', 'feb.9-13', 'arrived'], 'cana'),
#  (['cana', 'punta', 'arrived', 'hour'], 'feb.9-13'),
#  (['feb.9-13', 'cana', 'hour', 'ride'], 'arrived'),
#  (['arrived', 'feb.9-13', 'ride', 'airport'], 'hour'),
#  (['hour', 'arrived', 'airport', 'stopping'], 'ride'),
#  (['ride', 'hour', 'stopping', '3-4'], 'airport'),
#  (['airport', 'ride', '3-4', 'hotels'], 'stopping'),
#  (['stopping', 'airport', 'hotels', 'way'], '3-4'),
#  (['3-4', 'stopping', 'way', 'drop'], 'hotels'),
#  (['hotels', '3-4', 'drop', 'vacationers'], 'way'),
#  (['way', 'hotels', 'vacationers', 'check-in'], 'drop'),
#  (['drop', 'way', 'check-in', 'went'], 'vacationers'),
#  (['vacationers', 'drop', 'went', 'smoothly,'], 'check-in'),
#  (['check-in', 'vacationers', 'smoothly,', 'recommend'], 'went'),
#  (['went', 'check-in', 'recommend', 'getting'], 'smoothly,'),
#  (['smoothly,', 'went', 'getting', 'taxi'], 'recommend'),
#  (['recommend', 'smoothly,', 'taxi', 'unless'], 'getting'),
#  (['getting', 'recommend', 'unless', 'transfers'], 'taxi'),
#  (['taxi', 'getting', 'transfers', 'paid'], 'unless'),
#  (['unless', 'taxi', 'paid', 'advance,'], 'transfers'),
#  (['transfers', 'unless', 'advance,', 'pool'], 'paid'),
#  (['paid', 'transfers', 'pool', 'fabulous'], 'advance,'),
#  (['advance,', 'paid', 'fabulous', 'large'], 'pool'),
#  (['pool', 'advance,', 'large', 'winding'], 'fabulous'),
#  (['fabulous', 'pool', 'winding', 'swim-up'], 'large'),
#  (['large', 'fabulous', 'swim-up', 'bar'], 'winding'),
#  (['winding', 'large', 'bar', 'lots'], 'swim-up'),
#  (['swim-up', 'winding', 'lots', 'lounge'], 'bar'),
#  (['bar', 'swim-up', 'lounge', 'chairs'], 'lots'),
#  (['lots', 'bar', 'chairs', 'pick'], 'lounge'),
#  (['lounge', 'lots', 'pick', 'favorite'], 'chairs'),
#  (['chairs', 'lounge', 'favorite', 'lounging'], 'pick'),
#  (['pick', 'chairs', 'lounging', 'area,'], 'favorite'),
#  (['favorite', 'pick', 'area,', 'food'], 'lounging'),
#  (['lounging', 'favorite', 'food', 'available'], 'area,'),
#  (['area,', 'lounging', 'available', 'anytime'], 'food'),
#  (['food', 'area,', 'anytime', 'rate'], 'available'),
#  (['available', 'food', 'rate', 'average,'], 'anytime'),
#  (['anytime', 'available', 'average,', 'tried'], 'rate'),
#  (['rate', 'anytime', 'tried', 'japanese,'], 'average,'),
#  (['average,', 'rate', 'japanese,', 'room'], 'tried'),
#  (['tried', 'average,', 'room', 'smelled'], 'japanese,'),
#  (['japanese,', 'tried', 'smelled', 'musty'], 'room'),
#  (['room', 'japanese,', 'musty', 'probably'], 'smelled'),
#  (['smelled', 'room', 'probably', 'leaks'], 'musty'),
#  (['musty', 'smelled', 'leaks', 'bathroom'], 'probably'),
#  (['probably', 'musty', 'bathroom', 'commode'], 'leaks'),
#  (['leaks', 'probably', 'commode', 'sink'], 'bathroom'),
#  (['bathroom', 'leaks', 'sink', 'shower/tub,'], 'commode'),
#  (['commode', 'bathroom', 'shower/tub,', 'reported'], 'sink'),
#  (['sink', 'commode', 'reported', 'leaks'], 'shower/tub,'),
#  (['shower/tub,', 'sink', 'leaks', 'attended,'], 'reported'),
#  (['reported', 'shower/tub,', 'attended,', 'evening'], 'leaks'),
#  (['leaks', 'reported', 'evening', 'wanted'], 'attended,'),
#  (['attended,', 'leaks', 'wanted', 'use'], 'evening'),
#  (['evening', 'attended,', 'use', 'hair'], 'wanted'),
#  (['wanted', 'evening', 'hair', 'dryer'], 'use'),
#  (['use', 'wanted', 'dryer', 'knew'], 'hair'),
#  (['hair', 'use', 'knew', 'going'], 'dryer'),
#  (['dryer', 'hair', 'going', 'work'], 'knew'),
#  (['knew', 'dryer', 'work', 'not,'], 'going'),
#  (['going', 'knew', 'not,', 'did'], 'work'),
#  (['work', 'going', 'did', 'send'], 'not,'),
#  (['not,', 'work', 'send', 'complaint'], 'did'),
#  (['did', 'not,', 'complaint', 'wet'], 'send'),
#  (['send', 'did', 'wet', 'hair'], 'complaint'),
#  (['complaint', 'send', 'hair', 'dinner,'], 'wet'),
#  (['wet', 'complaint', 'dinner,', 'fuse'], 'hair'),
#  (['hair', 'wet', 'fuse', 'box'], 'dinner,'),
#  (['dinner,', 'hair', 'box', 'wall'], 'fuse'),
#  (['fuse', 'dinner,', 'wall', 'resetting'], 'box'),
#  (['box', 'fuse', 'resetting', 'help'], 'wall'),
#  (['wall', 'box', 'help', 'not,'], 'resetting'),
#  (['resetting', 'wall', 'not,', 'beautiful'], 'help'),
#  (['help', 'resetting', 'beautiful', 'view'], 'not,'),
#  (['not,', 'help', 'view', 'pool'], 'beautiful'),
#  (['beautiful', 'not,', 'pool', 'ocean,'], 'view'),
#  (['view', 'beautiful', 'ocean,', 'love'], 'pool'),
#  (['pool', 'view', 'love', 'gamble'], 'ocean,'),
#  (['ocean,', 'pool', 'gamble', 'casinos'], 'love'),
#  (['love', 'ocean,', 'casinos', 'available'], 'gamble'),
#  (['gamble', 'love', 'available', 'disappointed'], 'casinos'),
#  (['casinos', 'gamble', 'disappointed', 'breeze'], 'available'),
#  (['available', 'casinos', 'breeze', 'casino,'], 'disappointed'),
#  (['disappointed', 'available', 'casino,', 'played'], 'breeze'),
#  (['breeze', 'disappointed', 'played', 'roulette'], 'casino,'),
#  (['casino,', 'breeze', 'roulette', 'spinner/dealer'], 'played'),
#  (['played', 'casino,', 'spinner/dealer', 'fast'], 'roulette'),
#  (['roulette', 'played', 'fast', "n't"], 'spinner/dealer'),
#  (['spinner/dealer', 'roulette', "n't", 'chips'], 'fast'),
#  (['fast', 'spinner/dealer', 'chips', 'half'], "n't"),
#  (["n't", 'fast', 'half', 'time,'], 'chips'),
#  (['chips', "n't", 'time,', '2'], 'half'),
#  (['half', 'chips', '2', 'roulette'], 'time,'),
#  (['time,', 'half', 'roulette', 'tables'], '2'),
#  (['2', 'time,', 'tables', 'usually'], 'roulette'),
#  (['roulette', '2', 'usually', 'operating'], 'tables'),
#  (['tables', 'roulette', 'operating', '2'], 'usually'),
#  (['usually', 'tables', '2', 'black'], 'operating'),
#  (['operating', 'usually', 'black', 'jack'], '2'),
#  (['2', 'operating', 'jack', 'tables'], 'black'),
#  (['black', '2', 'tables', 'not'], 'jack'),
#  (['jack', 'black', 'not', 'slots'], 'tables'),
#  (['tables', 'jack', 'slots', 'pick,'], 'not'),
#  (['not', 'tables', 'pick,', 'think'], 'slots'),
#  (['slots', 'not', 'think', 'carribbean'], 'pick,'),
#  (['pick,', 'slots', 'carribbean', 'stud'], 'think'),
#  (['think', 'pick,', 'stud', 'table,'], 'carribbean'),
#  (['carribbean', 'think', 'table,', 'just'], 'stud'),
#  (['stud', 'carribbean', 'just', 'not'], 'table,'),
#  (['table,', 'stud', 'not', 'busy'], 'just'),
#  (['just', 'table,', 'busy', 'staff'], 'not'),
#  (['not', 'just', 'staff', 'did'], 'busy'),
#  (['busy', 'not', 'did', "n't"], 'staff'),
#  (['staff', 'busy', "n't", 'friendly'], 'did'),
#  (['did', 'staff', 'friendly', 'accomodating,'], "n't"),
#  (["n't", 'did', 'accomodating,', 'definitely'], 'friendly'),
#  (['friendly', "n't", 'definitely', 'recommend'], 'accomodating,'),
#  (['accomodating,', 'friendly', 'recommend', 'punta'], 'definitely'),
#  (['definitely', 'accomodating,', 'punta', 'cana'], 'recommend'),
#  (['recommend', 'definitely', 'cana', 'beautiful'], 'punta'),
#  (['punta', 'recommend', 'beautiful', 'beach'], 'cana'),
#  (['cana', 'punta', 'beach', 'ocean'], 'beautiful'),
#  (['beautiful', 'cana', 'ocean', 'try'], 'beach'),
#  (['beach', 'beautiful', 'try', 'newer'], 'ocean'),
#  (['ocean', 'beach', 'newer', 'hotels'], 'try'),
#  (['try', 'ocean', 'hotels', 'time,'], 'newer'),
#  (['choice', 'great', '2', 'nights,'], 'stayed'),
#  (['stayed', 'choice', 'nights,', 'fairly'], '2'),
#  (['2', 'stayed', 'fairly', 'new'], 'nights,'),
#  (['nights,', '2', 'new', 'hotel,'], 'fairly'),
#  (['fairly', 'nights,', 'hotel,', 'location'], 'new'),
#  (['new', 'fairly', 'location', 'great'], 'hotel,'),
#  (['hotel,', 'new', 'great', 'right'], 'location'),
#  (['location', 'hotel,', 'right', 'near'], 'great'),
#  (['great', 'location', 'near', 'attractions'], 'right'),
#  (['right', 'great', 'attractions', 'public'], 'near'),
#  (['near', 'right', 'public', 'transportation'], 'attractions'),
#  (['attractions', 'near', 'transportation', '2'], 'public'),
#  (['public', 'attractions', '2', 'blocks'], 'transportation'),
#  (['transportation', 'public', 'blocks', 'south'], '2'),
#  (['2', 'transportation', 'south', 'station,'], 'blocks'),
#  (['blocks', '2', 'station,', 'hotel'], 'south'),
#  (['south', 'blocks', 'hotel', 'great'], 'station,'),
#  (['station,', 'south', 'great', 'staff'], 'hotel'),
#  (['hotel', 'station,', 'staff', 'facilities'], 'great'),
#  (['great', 'hotel', 'facilities', 'amenities,'], 'staff'),
#  (['staff', 'great', 'amenities,', 'nice'], 'facilities'),
#  (['facilities', 'staff', 'nice', 'little'], 'amenities,'),
#  (['amenities,', 'facilities', 'little', 'spa'], 'nice'),
#  (['nice', 'amenities,', 'spa', 'area'], 'little'),
#  (['little', 'nice', 'area', 'pool'], 'spa'),
#  (['spa', 'little', 'pool', 'workout'], 'area'),
#  (['area', 'spa', 'workout', 'facilities,'], 'pool'),
#  (['pool', 'area', 'facilities,', 'room'], 'workout'),
#  (['workout', 'pool', 'room', 'great'], 'facilities,'),
#  (['facilities,', 'workout', 'great', 'nicely'], 'room'),
#  (['room', 'facilities,', 'nicely', 'furnished'], 'great'),
#  (['great', 'room', 'furnished', 'maintained'], 'nicely'),
#  (['nicely', 'great', 'maintained', 'lcd'], 'furnished'),
#  (['furnished', 'nicely', 'lcd', 'widescreen'], 'maintained'),
#  (['maintained', 'furnished', 'widescreen', 'tv'], 'lcd'),
#  (['lcd', 'maintained', 'tv', 'comfortable'], 'widescreen'),
#  (['widescreen', 'lcd', 'comfortable', 'bed'], 'tv'),
#  (['tv', 'widescreen', 'bed', 'clean'], 'comfortable'),
#  (['comfortable', 'tv', 'clean', 'quiet,'], 'bed'),
#  (['bed', 'comfortable', 'quiet,', 'staff'], 'clean'),
#  (['clean', 'bed', 'staff', 'informed'], 'quiet,'),
#  (['quiet,', 'clean', 'informed', 'friendly,'], 'staff'),
#  (['staff', 'quiet,', 'friendly,', 'price'], 'informed'),
#  (['informed', 'staff', 'price', 'reasonable'], 'friendly,'),
#  (['friendly,', 'informed', 'reasonable', 'area,'], 'price'),
#  (['price', 'friendly,', 'area,', 'overall'], 'reasonable'),
#  (['reasonable', 'price', 'overall', 'value'], 'area,'),
#  (['area,', 'reasonable', 'value', 'place'], 'overall'),
#  (['overall', 'area,', 'place', 'half'], 'value'),
#  (['value', 'overall', 'half', 'dozen'], 'place'),
#  (['place', 'value', 'dozen', 'places'], 'half'),
#  (['half', 'place', 'places', 'stayed'], 'dozen'),
#  (['dozen', 'half', 'stayed', 'boston'], 'places'),
#  (['places', 'dozen', 'boston', 'years,'], 'stayed'),
#  (['stayed', 'great', 'night', 'prior'], '1'),
#  (['1', 'stayed', 'prior', 'leaving'], 'night'),
#  (['night', '1', 'leaving', 'australia,'], 'prior'),
#  (['prior', 'night', 'australia,', 'previously'], 'leaving'),
#  (['leaving', 'prior', 'previously', 'sydney'], 'australia,'),
#  (['australia,', 'leaving', 'sydney', '1'], 'previously'),
#  (['previously', 'australia,', '1', 'week'], 'sydney'),
#  (['sydney', 'previously', 'week', 'stayed'], '1'),
#  (['1', 'sydney', 'stayed', 'city'], 'week'),
#  (['week', '1', 'city', 'centre,'], 'stayed'),
#  ...]

# %%
class NGramLanguageModeler(nn.Module):
    def __init__(self, vocab_size, embedding_dim, context_size):
        super(NGramLanguageModeler, self).__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.linear1 = nn.Linear(2* context_size * embedding_dim, 128)
        self.linear2 = nn.Linear(128, vocab_size)

    def forward(self, inputs):
        embeds = self.embeddings(inputs).view((1, -1))
        out = F.relu(self.linear1(embeds))
        out = self.linear2(out)
        log_probs = F.log_softmax(out, dim=1)
        return log_probs

# %%
losses = []
loss_function = nn.NLLLoss()
model = NGramLanguageModeler(len(vocab), EMBEDDING_DIM, CONTEXT_SIZE)
optimizer = optim.Adam(model.parameters(), lr=0.001)

for epoch in tqdm(range(EPOCHS_CBOW)):
    total_loss = 0
    for context, target in ngrams:

        # Prepare the inputs to be passed to the model (i.e, turn the words
        # into integer indices and wrap them in tensors)
        context_idxs = torch.tensor([word_to_ix[w] for w in context], dtype=torch.long)
        model.zero_grad()
        log_probs = model(context_idxs)
        loss = loss_function(log_probs, torch.tensor([word_to_ix[target]], dtype=torch.long))
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    print(f'Epoch {epoch+1} - Total loss: {total_loss}')
    losses.append(total_loss)
# Out:
#   0%|          | 0/10 [00:05<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [111], line 17
#      15     loss = loss_function(log_probs, torch.tensor([word_to_ix[target]], dtype=torch.long))
#      16     loss.backward()
# ---> 17     optimizer.step()
#      18     total_loss += loss.item()
#      19 print(f'Epoch {epoch+1} - Total loss: {total_loss}')
#
# File /usr/local/lib/python3.8/dist-packages/torch/optim/optimizer.py:373, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     368         else:
#     369             raise RuntimeError(
#     370                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     371             )
# --> 373 out = func(*args, **kwargs)
#     374 self._optimizer_step_code()
#     376 # call optimizer step post hooks
#
# File /usr/local/lib/python3.8/dist-packages/torch/optim/optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File /usr/local/lib/python3.8/dist-packages/torch/optim/adam.py:163, in Adam.step(self, closure)
#     152     beta1, beta2 = group['betas']
#     154     self._init_group(
#     155         group,
#     156         params_with_grad,
#    (...)
#     160         max_exp_avg_sqs,
#     161         state_steps)
# --> 163     adam(
#     164         params_with_grad,
#     165         grads,
#     166         exp_avgs,
#     167         exp_avg_sqs,
#     168         max_exp_avg_sqs,
#     169         state_steps,
#     170         amsgrad=group['amsgrad'],
#     171         beta1=beta1,
#     172         beta2=beta2,
#     173         lr=group['lr'],
#     174         weight_decay=group['weight_decay'],
#     175         eps=group['eps'],
#     176         maximize=group['maximize'],
#     177         foreach=group['foreach'],
#     178         capturable=group['capturable'],
#     179         differentiable=group['differentiable'],
#     180         fused=group['fused'],
#     181         grad_scale=getattr(self, "grad_scale", None),
#     182         found_inf=getattr(self, "found_inf", None),
#     183     )
#     185 return loss
#
# File /usr/local/lib/python3.8/dist-packages/torch/optim/adam.py:311, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     308 else:
#     309     func = _single_tensor_adam
# --> 311 func(params,
#     312      grads,
#     313      exp_avgs,
#     314      exp_avg_sqs,
#     315      max_exp_avg_sqs,
#     316      state_steps,
#     317      amsgrad=amsgrad,
#     318      beta1=beta1,
#     319      beta2=beta2,
#     320      lr=lr,
#     321      weight_decay=weight_decay,
#     322      eps=eps,
#     323      maximize=maximize,
#     324      capturable=capturable,
#     325      differentiable=differentiable,
#     326      grad_scale=grad_scale,
#     327      found_inf=found_inf)
#
# File /usr/local/lib/python3.8/dist-packages/torch/optim/adam.py:385, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     383 # Decay the first and second moment running average coefficient
#     384 exp_avg.lerp_(grad, 1 - beta1)
# --> 385 exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#     387 if capturable or differentiable:
#     388     step = step_t
#
# KeyboardInterrupt:

# %%
model_path = f'{MODEL_PATH}/ngram_model.pth'
torch.save(model.state_dict(), model_path)

# %% [markdown]
# ### Embedding?

# %% [markdown]
# ### LSTM

# %% [markdown]
# ### Gotowy model jakikolwiek
